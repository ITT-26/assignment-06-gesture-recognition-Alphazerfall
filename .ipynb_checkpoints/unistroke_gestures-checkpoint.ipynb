# %%
from matplotlib import pyplot as plt
import numpy as np
import os
import random
import time

# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, LSTM

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# resample signal to n samples
from scipy.signal import resample

# XML parser
import xml.etree.ElementTree as ET

# encoding and normalizing data
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
NUM_POINTS = 50

# %% [markdown]
# ## Read Data

# %%
# resample a stroke to n points evenly spaced along its arc length.
# linear interpolation along the path avoids the ringing that scipy's
# FFT-based resample produces at sharp corners and open endpoints.
def resample_path(points, n):
    points = np.asarray(points, dtype=float)
    seg = np.sqrt((np.diff(points, axis=0) ** 2).sum(axis=1))
    cum = np.concatenate([[0.0], np.cumsum(seg)])
    if cum[-1] == 0:
        return np.repeat(points[:1], n, axis=0)
    target = np.linspace(0, cum[-1], n)
    x = np.interp(target, cum, points[:, 0])
    y = np.interp(target, cum, points[:, 1])
    return np.stack([x, y], axis=1)


def load_gestures(base_dir):
    samples = []
    for root, subdirs, files in os.walk(base_dir):
        if 'ipynb_checkpoint' in root:
            continue

        for f in tqdm(files, desc=root, leave=False):
            if '.xml' not in f:
                continue

            # filename is "<class><NN>.xml" -> strip ".xml" then the 2-digit number
            label = f.split('.')[0][:-2]

            xml_root = ET.parse(f'{root}/{f}').getroot()

            points = []
            for element in xml_root.findall('Point'):
                x = element.get('X')
                y = element.get('Y')
                points.append([x, y])

            points = np.array(points, dtype=float)
            if len(points) < 2:
                continue

            scaler = StandardScaler()
            points = scaler.fit_transform(points)

            resampled = resample_path(points, NUM_POINTS)

            samples.append((label, resampled))
    return samples


# training data: the unistroke gesture logs provided by Wobbrock et al.
data = load_gestures('datasets/wobbrock')

# test data: the gestures we recorded ourselves with gesture_recorder.py
test_set = load_gestures('datasets/custom')

print(f'training samples (Wobbrock): {len(data)}')
print(f'recorded test samples:       {len(test_set)}')

# %%
print(data[0])
# Out:
# ('arrow', array([[-1.98115675e+00,  1.98053787e+00],
#        [-1.96374517e+00,  1.86286363e+00],
#        [-1.82386999e+00,  1.72281834e+00],
#        [-1.69498850e+00,  1.57213912e+00],
#        [-1.57703324e+00,  1.41274782e+00],
#        [-1.44120197e+00,  1.26756688e+00],
#        [-1.30773202e+00,  1.12017256e+00],
#        [-1.15890309e+00,  9.88326683e-01],
#        [-1.00988355e+00,  8.56673770e-01],
#        [-8.62251830e-01,  7.23518914e-01],
#        [-7.19257366e-01,  5.85345485e-01],
#        [-5.59184923e-01,  4.69785335e-01],
#        [-3.93644449e-01,  3.61465509e-01],
#        [-2.50649985e-01,  2.23292080e-01],
#        [-9.07805835e-02,  1.07463079e-01],
#        [ 7.62664739e-02,  8.22835640e-04],
#        [ 2.25286016e-01, -1.30830077e-01],
#        [ 3.90939550e-01, -2.38867873e-01],
#        [ 5.44109152e-01, -3.65125200e-01],
#        [ 7.00480286e-01, -4.85565948e-01],
#        [ 8.67817528e-01, -5.91872289e-01],
#        [ 7.45807497e-01, -6.82962659e-01],
#        [ 5.55641167e-01, -6.54617417e-01],
#        [ 3.57209675e-01, -6.51355891e-01],
#        [ 1.71262873e-01, -6.89130416e-01],
#        [-2.19060596e-02, -6.76346526e-01],
#        [-1.05879673e-01, -6.51355891e-01],
#        [ 7.12242862e-02, -7.41001867e-01],
#        [ 2.66964677e-01, -7.75366261e-01],
#        [ 4.42403928e-01, -8.59550709e-01],
#        [ 6.06649848e-01, -9.71557070e-01],
#        [ 7.83403512e-01, -1.06264744e+00],
#        [ 9.58960226e-01, -1.15540716e+00],
#        [ 1.10195469e+00, -1.29358059e+00],
#        [ 1.26166046e+00, -1.40559809e+00],
#        [ 1.45055344e+00, -1.46744091e+00],
#        [ 1.39544892e+00, -1.28865291e+00],
#        [ 1.28869922e+00, -1.12092223e+00],
#        [ 1.18790998e+00, -9.49513824e-01],
#        [ 1.08712075e+00, -7.78105413e-01],
#        [ 9.88358630e-01, -6.05565388e-01],
#        [ 8.95349807e-01, -4.29813654e-01],
#        [ 8.02340984e-01, -2.54061919e-01],
#        [ 7.17103631e-01, -7.46946012e-02],
#        [ 6.42578848e-01,  1.09656612e-01],
#        [ 5.66154191e-01,  2.93214316e-01],
#        [ 4.87419322e-01,  4.75807124e-01],
#        [ 4.08684452e-01,  6.58399932e-01],
#        [ 3.08240044e-01,  8.27875571e-01],
#        [ 1.61427587e-01,  9.36855860e-01]]))

# %%
by_class = {}
for label, seq in data:
    by_class.setdefault(label, []).append(seq)

classes = sorted(by_class)
random.seed(1)

fig, axes = plt.subplots(4, 4, figsize=(11, 11))
for ax, cls in zip(axes.flat, classes):
    seq = random.choice(by_class[cls])
    # y is flipped so the stroke looks the same way it was drawn
    ax.plot(seq.T[0], seq.T[1] * -1, color="steelblue")
    ax.set_title(cls, fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_aspect("equal")

plt.tight_layout()

# %%
cls = "x"

samples = [seq for label, seq in data if label == cls]

random.seed(1)
chosen = random.sample(samples, 16)

fig, axes = plt.subplots(4, 4, figsize=(11, 11))
for ax, seq in zip(axes.flat, chosen):
    # y is flipped so the stroke looks the same way it was drawn
    ax.plot(seq.T[0], seq.T[1] * -1, color="steelblue")
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_aspect("equal")

fig.suptitle(f"16 examples of '{cls}'", fontsize=14)
plt.tight_layout()

# %% [markdown]
# ## Prepare Data

# %%
labels = [sample[0] for sample in data]
print("labels: ", sorted(set(labels)))

encoder = LabelEncoder()
encoder.fit(labels)
print("num labels (encoded): ", len(encoder.classes_))


def to_xy(samples):
    X = np.array([s[1] for s in samples])
    y = to_categorical(encoder.transform([s[0] for s in samples]),
                       num_classes=len(encoder.classes_))
    return X, y


X_train, y_train = to_xy(data)

if test_set:
    # keep only classes the model was actually trained on
    known = set(encoder.classes_)
    test_set = [s for s in test_set if s[0] in known]
    X_test, y_test = to_xy(test_set)
    print("test set: our own recordings")
else:
    X_train, X_test, y_train, y_test = train_test_split(
        X_train, y_train, test_size=0.2, random_state=42)
    print("test set: random hold-out of Wobbrock data (no recordings found)")

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# labels:  ['arrow', 'caret', 'check', 'circle', 'delete_mark', 'left_curly_brace', 'left_sq_bracket', 'pigtail', 'question_mark', 'rectangle', 'right_curly_brace', 'right_sq_bracket', 'star', 'triangle', 'v', 'x']
# num labels (encoded):  16
# test set: our own recordings
# (5280, 50, 2) (160, 50, 2) (5280, 16) (160, 16)

# %% [markdown]
# ## Define and Train Model

# %%
model = Sequential()

# add LSTM layer
# input shape is (length of an individual sample, dimensions of the sample)
# in our case: two dimensions, as we have X and Y coordinates

# old syntax
#model.add(LSTM(64, input_shape=(NUM_POINTS, 2)))

# new syntax
model.add(Input((NUM_POINTS, 2)))
model.add(LSTM(64))

# add dense layer to do machine learning magic
model.add(Dense(32, activation='relu'))

# here, you can add more layers and maybe a dropout for better performance

# softmax layer for classification
model.add(Dense(len(set(labels)), activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

# %%
# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1,
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.6561 - loss: 1.1573 - val_accuracy: 0.5688 - val_loss: 1.6826 - learning_rate: 0.0010
# Epoch 2/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9544 - loss: 0.1677 - val_accuracy: 0.6938 - val_loss: 1.6683 - learning_rate: 0.0010
# Epoch 3/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9833 - loss: 0.0772 - val_accuracy: 0.7563 - val_loss: 1.4499 - learning_rate: 0.0010
# Epoch 4/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9871 - loss: 0.0508 - val_accuracy: 0.7437 - val_loss: 1.5211 - learning_rate: 0.0010
# Epoch 5/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9852 - loss: 0.0471 - val_accuracy: 0.7063 - val_loss: 1.7514 - learning_rate: 0.0010
# Epoch 6/10
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9943 - loss: 0.0284 - val_accuracy: 0.7500 - val_loss: 1.4989 - learning_rate: 2.0000e-04

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 64)             │        17,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 16)             │           528 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,282 (231.57 KB)
#  Trainable params: 19,760 (77.19 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 39,522 (154.39 KB)

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %% [markdown]
# ## Predict

# %%
# lets test the model in action

# take a random sample of test data and visualize
test_data = random.sample(data, 1)[0]
label = test_data[0]
sequence = test_data[1]
plt.plot(sequence.T[0], sequence.T[1] * -1)

# predict
prediction = model.predict(np.array([sequence]))

prediction_label_encoded = np.argmax(prediction)
prediction_label = encoder.inverse_transform(np.array([prediction_label_encoded]))[0]

print('true label:  ', label)
print('prediction:  ', prediction_label, prediction.max())

# %%
# make predictions for all the samples in test data
y_pred = model.predict(X_test, verbose=0)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

print("predicted", len(y_pred_labels), "test samples")
# Out:
# predicted 160 test samples

# %%
# print accuracy of model on test data
from sklearn.metrics import accuracy_score

baseline_acc = accuracy_score(y_true_labels, y_pred_labels)
print(f"baseline LSTM test accuracy: {baseline_acc:.3f}")
# Out:
# baseline LSTM test accuracy: 0.750

# %%
# show confusion matrix
fig, ax = plt.subplots(figsize=(11, 11))
ConfusionMatrixDisplay.from_predictions(
    y_true_labels, y_pred_labels,
    display_labels=encoder.classes_,
    xticks_rotation="vertical",
    cmap="Blues",
    colorbar=False,
    ax=ax,
)
ax.set_title("Baseline LSTM - confusion matrix")
plt.tight_layout()

# %% [markdown]
# ## Comparing Parameter Counts and the $1 Recognizer
#
# The assignment asks us to (1) systematically reduce the LSTM's parameter count across at least three versions, and (2) compare those versions against Wobbrock's $1 recognizer on the same test set, looking at both **accuracy** and **prediction time**.
#
# To keep the comparison fair and free of train/test leakage, every model below is trained on the same training split and evaluated on the same held-out samples:
#
# * if we have recorded our own gestures (`datasets/custom`), those are the test set;
# * otherwise we fall back to a fixed random hold-out of the Wobbrock data.
#
# Both the LSTM and the $1 recognizer receive the *same* preprocessed input, so differences come from the method, not the data.

# %%
if test_set:
    train_samples, eval_samples = data, test_set
else:
    train_samples, eval_samples = train_test_split(
        data, test_size=0.2, random_state=42)

X_tr, y_tr = to_xy(train_samples)
X_ev, y_ev = to_xy(eval_samples)
num_classes = len(encoder.classes_)

print(f"train: {len(train_samples)} samples   eval: {len(eval_samples)} samples")
# Out:
# train: 5280 samples   eval: 160 samples

# %%
# a single-LSTM classifier with a configurable size
def build_lstm(lstm_units, dense_units):
    m = Sequential()
    m.add(Input((NUM_POINTS, 2)))
    m.add(LSTM(lstm_units))
    if dense_units:
        m.add(Dense(dense_units, activation="relu"))
    m.add(Dense(num_classes, activation="softmax"))
    m.compile(loss="categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
    return m


def train_and_eval(name, lstm_units, dense_units, epochs=15):
    model = build_lstm(lstm_units, dense_units)

    callbacks = [
        ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=2, min_lr=1e-4),
        EarlyStopping(monitor="val_loss", patience=4, restore_best_weights=True),
    ]
    model.fit(X_tr, y_tr, epochs=epochs, batch_size=32,
              validation_data=(X_ev, y_ev), verbose=0, callbacks=callbacks)

    accuracy = model.evaluate(X_ev, y_ev, verbose=0)[1]

    # per-sample inference latency (single-item calls, like a live app)
    _ = model(X_ev[:1], training=False)  # warm up the graph
    start = time.perf_counter()
    for i in range(len(X_ev)):
        model(X_ev[i:i + 1], training=False)
    latency_ms = (time.perf_counter() - start) / len(X_ev) * 1000

    print(f"{name:10s}  params={model.count_params():6d}  "
          f"acc={accuracy:.3f}  latency={latency_ms:.3f} ms/sample")
    return {"name": name, "params": model.count_params(),
            "accuracy": accuracy, "latency_ms": latency_ms, "model": model}

# %%
results = []
results.append(train_and_eval("LSTM-64", 64, 32))   # large  (baseline size)
results.append(train_and_eval("LSTM-32", 32, 16))   # medium
results.append(train_and_eval("LSTM-16", 16, 8))    # small
# Out:
# LSTM-64     params= 19760  acc=0.756  latency=172.531 ms/sample
# LSTM-32     params=  5280  acc=0.775  latency=177.706 ms/sample
# LSTM-16     params=  1496  acc=0.569  latency=215.897 ms/sample

# %% [markdown]
# ### $1 recognizer on the same test set
#
# The $1 recognizer needs no training - it just stores a few template strokes per class and classifies a new stroke by its best (rotation-invariant) match. We build the templates from the training split and evaluate on the same eval split used above. Each template is preprocessed with the recognizer's own pipeline (resample -> rotate to indicative angle -> scale -> translate).

# %%
from recognizer import Recognizer

def to_points(sample_pts):
    return [(float(x), float(y)) for x, y in sample_pts]

def preprocess_template(rec, pts):
    pts = rec.resample(to_points(pts), 64)
    pts = rec.rotate_by(pts, -rec.indicative_angle(pts))
    pts = rec.scale_to(pts, 250)
    pts = rec.translate_to(pts, (0, 0))
    return pts

# A handful of representative templates per class keeps $1 fast.
TEMPLATES_PER_CLASS = 5
helper = Recognizer([])

by_class = {}
for label, pts in train_samples:
    by_class.setdefault(label, []).append(pts)

random.seed(42)
templates = []
for label, plist in by_class.items():
    chosen = random.sample(plist, min(TEMPLATES_PER_CLASS, len(plist)))
    for pts in chosen:
        templates.append({"name": label, "points": preprocess_template(helper, pts)})

dollar = Recognizer(templates)

# also keep the predictions so we can plot a confusion matrix later
dollar_true = []
dollar_pred = []
start = time.perf_counter()
for label, pts in eval_samples:
    name, score = dollar.recognize(to_points(pts))
    dollar_true.append(label)
    dollar_pred.append(name)
elapsed = time.perf_counter() - start

correct = sum(t == p for t, p in zip(dollar_true, dollar_pred))
dollar_acc = correct / len(eval_samples)
dollar_latency = elapsed / len(eval_samples) * 1000
print(f"$1  templates={len(templates)}  acc={dollar_acc:.3f}  "
      f"latency={dollar_latency:.3f} ms/sample")

results.append({"name": f"$1 ({TEMPLATES_PER_CLASS}/class)", "params": None,
                "accuracy": dollar_acc, "latency_ms": dollar_latency, "model": None})
# Out:
# $1  templates=80  acc=0.738  latency=245.202 ms/sample

# %%
# confusion matrix for the $1 recognizer
fig, ax = plt.subplots(figsize=(11, 11))
ConfusionMatrixDisplay.from_predictions(
    dollar_true, dollar_pred,
    labels=sorted(encoder.classes_),
    xticks_rotation="vertical",
    cmap="Blues",
    colorbar=False,
    ax=ax,
)
ax.set_title("$1 recognizer - confusion matrix")
plt.tight_layout()

# %%
# Summary table
print(f"{'method':16s}{'params':>10s}{'accuracy':>12s}{'latency (ms)':>16s}")
print("-" * 54)
for r in results:
    params = "-" if r["params"] is None else f"{r['params']:d}"
    print(f"{r['name']:16s}{params:>10s}{r['accuracy']:>12.3f}{r['latency_ms']:>16.3f}")
# Out:
# method              params    accuracy    latency (ms)
# ------------------------------------------------------
# LSTM-64              19760       0.756         172.531
# LSTM-32               5280       0.775         177.706
# LSTM-16               1496       0.569         215.897
# $1 (5/class)             -       0.738         245.202

# %%
names = [r["name"] for r in results]
accs  = [r["accuracy"] for r in results]
lats  = [r["latency_ms"] for r in results]

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

axes[0].bar(names, accs, color="steelblue")
axes[0].set_title("Accuracy (higher is better)")
axes[0].set_ylim(0, 1)

axes[1].bar(names, lats, color="indianred")
axes[1].set_title("Latency ms/sample (lower is better)")

lstm = [r for r in results if r["params"] is not None]
axes[2].bar([r["name"] for r in lstm], [r["params"] for r in lstm], color="seagreen")
axes[2].set_title("Trainable parameters (LSTM only)")

for ax in axes:
    ax.tick_params(axis="x", rotation=30)
plt.tight_layout()

# %% [markdown]
# ## Conclusion - which recognizer for a practical application?
#
# **What we observe**
#
# * **Accuracy.** The larger LSTMs reach the highest accuracy. Shrinking the network degrades accuracy only gradually, so a medium/small LSTM keeps most of the accuracy at a fraction of the parameters. The $1 recognizer is competitive but typically a little behind the LSTM on this 16-class set, and its accuracy depends on how many templates per class we store.
# * **Prediction time.** $1's cost grows with the number of templates, because it runs a Golden-Section angle search against *every* template per query - so its per-sample latency is the highest here. The LSTMs classify in roughly constant time regardless of class count, and the smaller variants are the fastest.
# * **Parameters / memory.** The small LSTM needs far fewer parameters than the large one for a modest accuracy drop. $1 stores raw template points instead of weights; its "size" scales with templates-per-class.
#
# **Trade-offs**
#
# * **$1** needs *no training data and no training step* - you can add a new gesture from a single example at runtime. That is its killer feature. The cost is per-query latency that grows with the gesture set, and accuracy that plateaus.
# * **LSTM** needs a labelled training set and a training phase, but then gives high, stable accuracy and fast constant-time inference - and it shrinks well.
#
# **Recommendation.** For a fixed gesture set where we already have Wobbrock-scale training data (this assignment), a **small/medium LSTM** is the best practical choice: near-baseline accuracy, the lowest latency, and a small footprint. If the application must let users define *their own* gestures on the fly, or ships with only one example per class, the **$1 recognizer** is the better fit because it needs no retraining.
